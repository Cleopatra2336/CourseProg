# %%
import pandas as pd 
df = pd.read_csv('employee_reviews.csv')

# %% [markdown]
# 1. Провести первичный анализ данных (размеры таблицы, типы данных в таблице, статистическое описание)

# %%
df.info(memory_usage='deep')
df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67529 entries, 0 to 67528
# Data columns (total 17 columns):
# Unnamed: 0                    67529 non-null int64
# company                       67529 non-null object
# location                      67529 non-null object
# dates                         67529 non-null object
# job-title                     67529 non-null object
# summary                       67409 non-null object
# pros                          67529 non-null object
# cons                          67529 non-null object
# advice-to-mgmt                67232 non-null object
# overall-ratings               67529 non-null float64
# work-balance-stars            67529 non-null object
# culture-values-stars          67529 non-null object
# carrer-opportunities-stars    67529 non-null object
# comp-benefit-stars            67529 non-null object
# senior-mangemnet-stars        67529 non-null object
# helpful-count                 67529 non-null int64
# ...

# %% [markdown]
# 2. Отсортировать данные по какому-либо признаку.

# %%
df.sort_values(['dates', 'company'], ascending=[True, False])
# Out:
#        Unnamed: 0    company                      location         dates  \
# 46378       46379      apple                 Cupertino, CA   Apr 1, 2009
# 25082       25083     amazon                   Seattle, WA   Apr 1, 2009
# 60917       60918  microsoft                   Redmond, WA   Apr 1, 2010
# 46234       46235      apple                 Cupertino, CA   Apr 1, 2010
# 60416       60417  microsoft                  Bellevue, WA   Apr 1, 2011
# 67428       67429  microsoft                          none   Apr 1, 2011
# 49251       49252      apple          London, England (UK)   Apr 1, 2011
# 36358       36359    netflix                 Hillsboro, OR   Apr 1, 2012
# 59943       59944  microsoft                   Redmond, WA   Apr 1, 2012
# 59951       59952  microsoft                   Redmond, WA   Apr 1, 2012
# 59965       59966  microsoft                   Seattle, WA   Apr 1, 2012
# 67058       67059  microsoft                          none   Apr 1, 2012
# ...

# %% [markdown]
# ###3. Удалить столбец\строку в таблице

# %%
df.drop('job-title', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-38c6b6547e31> in <module>
# ----> 1 df.drop('job-title', axis=1, inplace=True)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...

# %% [markdown]
# ###4. Посчитать количество уникальных значений в таблице(столбце).

# %%
df.company.nunique()
# Out:
# 6

# %% [markdown]
# ###5. Найти минимум и максимум некоторого признака.

# %%
df[df['helpful-count'] == df['helpful-count'].max()].head()
# Out:
#    Unnamed: 0 company           location          dates  \
# 1           2  google  Mountain View, CA   Jun 21, 2013
#
#                                              summary  \
# 1  Moving at the speed of light, burn out is inev...
#
#                                                 pros  \
# 1  1) Food, food, food. 15+ cafes on main campus ...
#
#                                                 cons  \
# 1  1) Work/life balance. What balance? All those ...
#
#                                       advice-to-mgmt  overall-ratings  \
# 1  1) Don't dismiss emotional intelligence and ad...              4.0
#
#   work-balance-stars culture-values-stars carrer-opportunities-stars  \
# 1                2.0                  3.0                        3.0
#
#   comp-benefit-stars senior-mangemnet-stars  helpful-count  \
# 1                5.0                    3.0           2094
#
#                                                 link
# 1  https://www.glassdoor.com/Reviews/Google-Revie...

# %%
df[df['dates'] == df['dates'].min()].head()
# Out:
#        Unnamed: 0 company       location         dates  \
# 25082       25083  amazon    Seattle, WA   Apr 1, 2009
# 46378       46379   apple  Cupertino, CA   Apr 1, 2009
#
#                                                  summary  \
# 25082  Petty resentments thrive within management at ...
# 46378  Some flaws, but in general a fantastic place t...
#
#                                                     pros  \
# 25082  There is no explicit path to promotion. One da...
# 46378                    Coworkers are very high quality
#
#                                                     cons  \
# 25082  There is no explicit path to promotion. One da...
# 46378  Management are just people good at their job, ...
#
#                                           advice-to-mgmt  overall-ratings  \
# 25082  Walk the talk. Amazon boasts about how working...              3.0
# 46378  Promote better managers rather than good perfo...              4.0
#
# ...

# %% [markdown]
# ###6. Переименовать столбец.

# %%
df.rename({'company':'company-name'}, axis=1)
# Out:
#        Unnamed: 0 company-name           location          dates  \
# 0               1       google               none   Dec 11, 2018
# 1               2       google  Mountain View, CA   Jun 21, 2013
# 2               3       google       New York, NY   May 10, 2014
# 3               4       google  Mountain View, CA    Feb 8, 2015
# 4               5       google    Los Angeles, CA   Jul 19, 2018
# 5               6       google  Mountain View, CA    Dec 9, 2018
# 6               7       google       New York, NY   Dec 11, 2018
# 7               8       google               none   Dec 11, 2018
# 8               9       google       New York, NY   Dec 10, 2018
# 9              10       google               none    Dec 9, 2018
# 10             11       google  Mountain View, CA    Dec 8, 2018
# 11             12       google               none    Dec 8, 2018
# 12             13       google               none    Dec 4, 2018
# ...

# %% [markdown]
# ###7. Используя loc(iloc) отфильтровать данные.

# %%
df.loc[:, ['company', 'location']]
df.loc[:,['company', 'location',]].sort_values('location',)
# Out:
#          company                                     location
# 19114     amazon                                 Aberdeen, MD
# 42886      apple                                 Aberdeen, SD
# 47119      apple                      Aberdeen, Scotland (UK)
# 6793      google                          Abha (Saudi Arabia)
# 63206  microsoft                      Abidjan (Cote d'Ivoire)
# 32398     amazon                      Abidjan (Cote d'Ivoire)
# 49511      apple                      Abidjan (Cote d'Ivoire)
# 47491      apple  Abu Dhabi, Abu Dhabi (United Arab Emirates)
# 48216      apple  Abu Dhabi, Abu Dhabi (United Arab Emirates)
# 46787      apple  Abu Dhabi, Abu Dhabi (United Arab Emirates)
# 47451      apple  Abu Dhabi, Abu Dhabi (United Arab Emirates)
# 47276      apple  Abu Dhabi, Abu Dhabi (United Arab Emirates)
# 28403     amazon  Abu Dhabi, Abu Dhabi (United Arab Emirates)
# 48531      apple  Abu Dhabi, Abu Dhabi (United Arab Emirates)
# ...

# %% [markdown]
# ###8. Сгруппировать данные по какому-либо признаку.

# %%
df.groupby('company')['location'].agg([ 'min', 'max'])
# Out:
#                                min                                   max
# company
# amazon                Aberdeen, MD  Ḩawwārah, Amman Governorate (Jordan)
# apple                 Aberdeen, SD                                  none
# facebook               Alameda, CA           Ālipur, Sylhet (Bangladesh)
# google         Abha (Saudi Arabia)                         Ţanţā (Egypt)
# microsoft  Abidjan (Cote d'Ivoire)  Ḩawwārah, Amman Governorate (Jordan)
# netflix    Amsterdam (Netherlands)                                  none

# %%
df.head(2)
# Out:
#    Unnamed: 0 company           location          dates  \
# 0           1  google               none   Dec 11, 2018
# 1           2  google  Mountain View, CA   Jun 21, 2013
#
#                                job-title  \
# 0  Current Employee - Anonymous Employee
# 1      Former Employee - Program Manager
#
#                                              summary  \
# 0                           Best Company to work for
# 1  Moving at the speed of light, burn out is inev...
#
#                                                 pros  \
# 0                      People are smart and friendly
# 1  1) Food, food, food. 15+ cafes on main campus ...
#
#                                                 cons  \
# 0                 Bureaucracy is slowing things down
# 1  1) Work/life balance. What balance? All those ...
#
#                                       advice-to-mgmt  overall-ratings  \
# 0                                               none              5.0
# ...

# %% [markdown]
# ###9. Используя value counts посчитать некоторый признак.

# %%
df['company'].value_counts().head(5)
df['mostLocation'] = df['location'].apply
df.head()
# Out:
#    Unnamed: 0 company           location          dates  \
# 0           1  google               none   Dec 11, 2018
# 1           2  google  Mountain View, CA   Jun 21, 2013
# 2           3  google       New York, NY   May 10, 2014
# 3           4  google  Mountain View, CA    Feb 8, 2015
# 4           5  google    Los Angeles, CA   Jul 19, 2018
#
#                                   job-title  \
# 0     Current Employee - Anonymous Employee
# 1         Former Employee - Program Manager
# 2  Current Employee - Software Engineer III
# 3     Current Employee - Anonymous Employee
# 4       Former Employee - Software Engineer
#
#                                              summary  \
# 0                           Best Company to work for
# 1  Moving at the speed of light, burn out is inev...
# 2  Great balance between big-company security and...
# 3  The best place I've worked and also the most d...
# 4                    Unique, one of a kind dream job
#
# ...
